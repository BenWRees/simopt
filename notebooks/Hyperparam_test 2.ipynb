# %% [markdown]
# # Demo script for the ProblemSolver class.
#
# This script is intended to help with debugging problems and solvers.
#
# It create a problem-solver pairing (using the directory) and runs multiple macroreplications of the solver on the problem.

# %% [markdown]
# ## Append SimOpt Path
#
# Since the notebook is stored in simopt/notebooks, we need to append the parent simopt directory to the system path to import the necessary modules later on.

# %%
import sys
from pathlib import Path

# Take the current directory, find the parent, and add it to the system path
sys.path.append(str(Path.cwd().parent))

# %% [markdown]
# ## Configuration Parameters
#
# This section defines the core parameters for the demo.
#
# To query model/problem/solver names, run `python scripts/list_directories.py`

# %%
# Specify the names of the solver and problem to test.
# Example with random search solver on continuous newsvendor problem:
# solver_abbr_name = "RNDSRCH"
# problem_abbr_name = "CNTNEWS-1"
solver_abbr_name = "MixedIntTRSolver"
problem_abbr_name = "ASTROMORF-HYPEROPT-2"

num_macroreps = 1
num_postreps = 2
num_postreps_init_opt = 2

# %%
# If the solver runs have already been performed, specify the file name path.
# If no path is specified, a new run will be performed.
file_name_path = None

if file_name_path is None:
    # Import the ProblemSolver class and other useful functions
    from simopt.experiment_base import ProblemSolver, instantiate_problem

    target_problem = instantiate_problem(problem_name='DYNAMNEWS-1')

    model_fixed_factors = {
        "target_problem": target_problem,
        "n_macroreps": 5,
        # "gamma_1": 2.5,
        # "gamma_2": 1.2,
        # "gamma_3": 0.5,
        "consistency_weight": 0.1,
        "quality_weight": 0.9
    }	
    budget = 500
    problem_fixed_factors = {
        "max_dimension": 9,
        "max_degree": 5,
        "budget": budget,
    }
    solver_fixed_factors = {
        'lambda_min': 2
    }
    # Initialize an instance of the experiment class.
    myexperiment = ProblemSolver(solver_abbr_name, problem_abbr_name, problem_fixed_factors=problem_fixed_factors, model_fixed_factors=model_fixed_factors)

    # Run a fixed number of macroreplications of the solver on the problem.
    myexperiment.run(n_macroreps=num_macroreps)
else:
    # following pair of lines (and uncomment the myexperiment.run(...)
    # line above) to read in results from a .pickle file.
    # file_name_path = ""
    from simopt.experiment_base import read_experiment_results

    myexperiment = read_experiment_results(file_name_path)
# Out:
# Starting iteration 1 with budget remaining 500...
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -135.7201358330732, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -139.8922945365528, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -155.02861758411998, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -139.95792979697026, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -120.0, std_obj = 0.0
# Constructing model...
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 4, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.5089889128553, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 4, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -158.82127729686528, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 4, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -162.83605013358533, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 4, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.9053520815933, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 4, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.31188508611987, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 2, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -162.5212069657798, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 2, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -159.2175581538789, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 2, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -137.6569512202011, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 2, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -138.9297589941584, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 2, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -100.87899279326203, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=3, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 3, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -120.0, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=3, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 3, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -100.88429514308687, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=3, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 3, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.308882283587, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=3, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 3, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -135.92428682213992, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=3, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 3, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -122.79191013383902, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -158.08415117773785, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -164.75210122084613, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -157.50406927339938, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -156.58978652326547, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -161.1302253136823, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -120.0, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -159.00873448291907, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -100.68585991016869, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90535208159406, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -159.60791347010033, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.01000001, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.01000001, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.01000001]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.01000001, subproblem_regularisation 0.5: mean_obj = -139.90535398805042, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.01000001, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.01000001, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.01000001]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.01000001, subproblem_regularisation 0.5: mean_obj = -139.90535208159397, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.01000001, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.01000001, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.01000001]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.01000001, subproblem_regularisation 0.5: mean_obj = -139.90490540983762, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.01000001, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.01000001, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.01000001]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.01000001, subproblem_regularisation 0.5: mean_obj = -139.90459640470178, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.01000001, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.01000001, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.01000001]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.01000001, subproblem_regularisation 0.5: mean_obj = -139.90507830669242, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.6677992676220694, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 2.6677992676220694, 1.01000001] -> [2.6677992676220694, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.6677992676220694, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -100.4927094292037, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.6677992676220694, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 2.6677992676220694, 1.01000001] -> [2.6677992676220694, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.6677992676220694, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -120.59594761928807, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.6677992676220694, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 2.6677992676220694, 1.01000001] -> [2.6677992676220694, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.6677992676220694, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90535536083055, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.6677992676220694, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 2.6677992676220694, 1.01000001] -> [2.6677992676220694, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.6677992676220694, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.50727078648845, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.6677992676220694, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 2.6677992676220694, 1.01000001] -> [2.6677992676220694, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.6677992676220694, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -140.36996082292154, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.01000001, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.01000001, 1.01000001] -> [1.01000001, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.01000001, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90535099676688, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.01000001, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.01000001, 1.01000001] -> [1.01000001, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.01000001, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -108.85407168482517, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.01000001, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.01000001, 1.01000001] -> [1.01000001, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.01000001, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.70433410892872, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.01000001, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.01000001, 1.01000001] -> [1.01000001, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.01000001, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -159.21754414527203, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.01000001, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.01000001, 1.01000001] -> [1.01000001, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.01000001, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -120.0, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.4677992776220696, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.4677992776220696] -> [2.4677992776220696, 1.2, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.4677992776220696, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -162.88206965880312, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.4677992776220696, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.4677992776220696] -> [2.4677992776220696, 1.2, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.4677992776220696, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -162.19490296117058, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.4677992776220696, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.4677992776220696] -> [2.4677992776220696, 1.2, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.4677992776220696, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90535135962716, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.4677992776220696, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.4677992776220696] -> [2.4677992776220696, 1.2, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.4677992776220696, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -100.0946415354826, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.4677992776220696, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.4677992776220696] -> [2.4677992776220696, 1.2, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 2.4677992776220696, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -130.24827763721038, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=1.9677992676220695.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 1.9677992676220695: mean_obj = -162.84903442976122, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=1.9677992676220695.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 1.9677992676220695: mean_obj = -116.25799333298782, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=1.9677992676220695.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 1.9677992676220695: mean_obj = -135.92428682213992, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=1.9677992676220695.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 1.9677992676220695: mean_obj = -136.40861283460296, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=1.9677992676220695.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.01000001] -> [1.2, 1.01000001, 0.9899999899999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.01000001, gamma_3 0.9899999899999999, subproblem_regularisation 1.9677992676220695: mean_obj = -150.76063921592493, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.01000001, gamma_3=0.9899999899999999, subproblem_regularisation=0.01000001.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# ...
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.0100000099999997, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.0100000099999997] -> [1.2, 1.0100000099999997, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.0100000099999997, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -158.21085559027222, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.0100000099999997, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.0100000099999997] -> [1.2, 1.0100000099999997, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.0100000099999997, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -152.27568129032946, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.0100000099999997, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.0100000099999997] -> [1.2, 1.0100000099999997, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.0100000099999997, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -153.29187354133649, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.0100000099999997, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.0100000099999997] -> [1.2, 1.0100000099999997, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.0100000099999997, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -159.70485188624627, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.0100000099999997, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.0100000099999997] -> [1.2, 1.0100000099999997, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.0100000099999997, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -162.6752940063342, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=1, gamma_1=1.2, gamma_2=1.0100000099999997, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 1.0100000099999997] -> [1.2, 1.0100000099999997, 0.9899999899999999]
# for dimension 3, degree 1, gamma_1 1.2, gamma_2 1.0100000099999997, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -149.56432666157335, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 4, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90535717009118, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 4, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90533217401165, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 4, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.90535636861676, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 4, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -157.64470701923207, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 4, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -167.53160727742264, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=4, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 4
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 4, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -160.00977083968, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 2, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -139.9053280469281, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# for dimension 2, degree 1, gamma_1 2.0100000099999997, gamma_2 1.2, gamma_3 0.9899999899999999, subproblem_regularisation 0.5: mean_obj = -149.87556801718685, std_obj = 0.0
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=2, degree=1, gamma_1=2.0100000099999997, gamma_2=1.2, gamma_3=0.9899999899999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
#
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 2
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.9899999899999999, 1.2, 2.0100000099999997] -> [2.0100000099999997, 1.2, 0.9899999899999999]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 33
#      30     myexperiment = ProblemSolver(solver_abbr_name, problem_abbr_name, problem_fixed_factors=problem_fixed_factors, model_fixed_factors=model_fixed_factors)
#      32     # Run a fixed number of macroreplications of the solver on the problem.
# ---> 33     myexperiment.run(n_macroreps=num_macroreps)
#      34 else:
#      35     # following pair of lines (and uncomment the myexperiment.run(...)
#      36     # line above) to read in results from a .pickle file.
#      37     # file_name_path = ""
#      38     from simopt.experiment_base import read_experiment_results
#
# File ~/Desktop/simopt/simopt/experiment_base.py:575, in ProblemSolver.run(self, n_macroreps, n_jobs)
#     573 	results: list[tuple] = [run_multithread_partial(i) for i in range(n_macroreps)]
#     574 else:
# --> 575 	results: list[tuple] = Parallel(n_jobs=n_jobs)(
#     576 		delayed(run_multithread_partial)(i) for i in range(n_macroreps)
#     577 	)  # type: ignore
#     579 for mrep, recommended_xs, intermediate_budgets, timing, iterations, fn_estimates, budget_history in results:
#     580 	self.all_recommended_xs[mrep] = recommended_xs
#
# File /opt/anaconda3/envs/simopt/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/anaconda3/envs/simopt/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/anaconda3/envs/simopt/lib/python3.12/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# Run a fixed number of postreplications at all recommended solutions.
myexperiment.post_replicate(n_postreps=num_postreps)
# Out:
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -163.779458826917, std_obj = 9.94855132258431e-06
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -163.779458826917, std_obj = 9.94855132258431e-06
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -163.779458826917, std_obj = 9.94855132258431e-06
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -163.779458826917, std_obj = 9.94855132258431e-06

# %%
# Find an optimal solution x* for normalization.
from simopt.experiment_base import post_normalize

post_normalize([myexperiment], n_postreps_init_opt=num_postreps_init_opt)
# Out:
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.5, gamma_2=1.2, gamma_3=0.5, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# for dimension 3, degree 2, gamma_1 2.5, gamma_2 1.2, gamma_3 0.5, subproblem_regularisation 0.5: mean_obj = -147.60328307779574, std_obj = 0.9557768107203871
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=2.5, gamma_2=1.2, gamma_3=0.5, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 2.5, gamma_2 1.2, gamma_3 0.5, subproblem_regularisation 0.5: mean_obj = -147.60328307779574, std_obj = 0.9557768107203871
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# WARNING:root:Reordering gamma values to satisfy gamma_1 >= gamma_2 >= gamma_3: [0.99999999, 1.2, 1.00000001] -> [1.2, 1.00000001, 0.99999999]
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -163.779458826917, std_obj = 9.94855132258431e-06
# Evaluating ASTROMORF on DYNAMNEWS-1 with dimension=3, degree=2, gamma_1=1.2, gamma_2=1.00000001, gamma_3=0.99999999, subproblem_regularisation=0.5.
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# RUNNING ASTROMoRF SOLVER ON PROBLEM: DYNAMNEWS-1 WITH SUBSPACE DIMENSION 3
# for dimension 3, degree 2, gamma_1 1.2, gamma_2 1.00000001, gamma_3 0.99999999, subproblem_regularisation 0.5: mean_obj = -163.779458826917, std_obj = 9.94855132258431e-06

# %%
# Log results.
myexperiment.log_experiment_results()

# %%
# Produce basic plots.
# %matplotlib inline
from simopt.experiment_base import (
    PlotType,
    plot_progress_curves,
    plot_terminal_progress,
    plot_solvability_cdfs,
)

print("Plotting results...")

# print the terminal solution 
for terminal_macrorep in myexperiment.all_recommended_xs : 
    print(terminal_macrorep[-1])



def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_progress_curves(
        experiments=[myexperiment], plot_type=PlotType.ALL, normalize=False
    )
)
_print_path(
    plot_progress_curves(
        experiments=[myexperiment], plot_type=PlotType.MEAN, normalize=False
    )
)

_print_path(
    plot_terminal_progress(
        experiments=[myexperiment], plot_type=PlotType.BOX, normalize=False
    )
)


print("Plotting complete!")
# Out:
# Plotting results...
# (3.0, 2.0, 0.99999999, 1.2, 1.00000001, 0.5)
# Plot saved to [PosixPath('/Users/benjaminrees/Desktop/simopt/experiments/2025-11-26_22-29-43/plots/SOLVER_SET_ASTROMORF-HYPEROPT-2_all_prog_curves_unnorm.png')]
# Plot saved to [PosixPath('/Users/benjaminrees/Desktop/simopt/experiments/2025-11-26_22-29-43/plots/SOLVER_SET_ASTROMORF-HYPEROPT-2_mean_prog_curve_unnorm.png')]
# Plot saved to [PosixPath('/Users/benjaminrees/Desktop/simopt/experiments/2025-11-26_22-29-43/plots/SOLVER_SET_ASTROMORF-HYPEROPT-2_terminal_box_unnorm.png')]
# Plotting complete!

# %% [markdown]
# # Demo for the ProblemsSolvers class.
#
# This script is intended to help with debugging problems and solvers.
#
# It create problem-solver groups (using the directory) and runs multiple macroreplications of each problem-solver pair.

# %% [markdown]
# ## Append SimOpt Path
#
# Since the notebook is stored in simopt/notebooks, we need to append the parent simopt directory to the system path to import the necessary modules later on.

# %%
import sys
from pathlib import Path

# Take the current directory, find the parent, and add it to the system path
sys.path.append(str(Path.cwd().parent))

# %% [markdown]
# ## Configuration Parameters
#
# This section defines the core parameters for the demo.
#
# To query model/problem/solver names, run `python scripts/list_directories.py`

# %%
# Specify the names of the solver(s) and problem(s) to test.
solver_abbr_names = ["ASTROMORF", "ADAM", "NELDMD", "RNDSRCH", "STRONG", "ASTRODF"]
# problem_abbr_names = ["NETWORK-1", "ROSENBROCK-1", "SAN-1","DYNAMNEWS-1", "IRONORECONT-1", "SSCONT-1"]
problem_abbr_names = ["SAN-1", "NETWORK-1", "DYNAMNEWS-1", "ROSENBROCK-1", "SSCONT-1"]

num_macroreps = 5
num_postreps = 30
num_postreps_init_opt = 30

# %%
# Function that instantiates a problem instance given its name and scales the dimension of the problem for a given dimension argument
from simopt.experiment_base import instantiate_problem, instantiate_solver, Problem, ProblemsSolvers, ProblemSolver
import numpy as np
import random
import hashlib

SCALABLE_PROBLEMS = ["FIXEDSAN-1", "NETWORK-1", "ROSENBROCK-1", "SAN-1", "DYNAMNEWS-1", "FACSIZE-2", "FACSIZE-1", "CONTAM-2"]

def scale_dimension(problem_name: str, budget: int, dimension: int | None = None) -> Problem:
    """
    Instantiate a problem with a scaled dimension.
    
    All model and problem factors that depend on the dimension are updated
    before instantiation to ensure consistency.
    
    Args:
        problem_name: The abbreviated name of the problem (e.g., "FACSIZE-2")
        dimension: The desired dimension for the problem
        
    Returns:
        A Problem instance configured for the specified dimension
    """
    if problem_name not in SCALABLE_PROBLEMS or dimension is None:
        # For non-scalable problems, just instantiate with defaults
        return instantiate_problem(problem_name, {'budget': budget})
    
    # Build the factors for the new dimension
    model_factors = get_scaled_model_factors(problem_name, dimension)
    problem_factors = get_scaled_problem_factors(problem_name, dimension)
    problem_factors['budget'] = budget
    
    # Instantiate the problem with the scaled factors
    problem = instantiate_problem(
        problem_name,
        problem_fixed_factors=problem_factors,
        model_fixed_factors=model_factors
    )
    
    # Set the problem dimension explicitly
    problem.dim = dimension
    
    # Post-initialization updates for factors that can't be validated during construction
    post_init_updates(problem, problem_name, dimension)
    
    return problem


def get_scaled_model_factors(problem_name: str, dimension: int) -> dict:
    """
    Generate model factors scaled to the specified dimension.
    
    Args:
        problem_name: The abbreviated name of the problem
        dimension: The target dimension
        
    Returns:
        Dictionary of model factors appropriate for the dimension
    """
    # Deterministic RNGs based on problem name + dimension
    seed = int(hashlib.sha256(f"{problem_name}:{dimension}".encode()).hexdigest(), 16) % (2**32)
    rng_py = random.Random(seed)
    rng_np = np.random.default_rng(seed)

    if problem_name == 'DYNAMNEWS-1':
        return {
            'num_prod': dimension,
            'c_utility': [float(6 + j) for j in range(dimension)],
            'init_level': [3] * dimension,
            'price': [9.0] * dimension,
            'cost': [5.0] * dimension,
        }
    
    elif problem_name in ('FACSIZE-1', 'FACSIZE-2'):
        # Use diagonal covariance to avoid expensive Cholesky and reduce rejection rate
        # With mean=500 and std=50 (variance=2500), P(X<0) ≈ 0 for each dimension
        # This makes rejection sampling nearly instant
        variance = 2500.0  # std = 50, mean = 500, so P(X<0) is negligible
        cov_matrix = np.eye(dimension) * variance
        return {
            'mean_vec': [500.0] * dimension,
            'cov': cov_matrix.tolist(),
            'capacity': [float(rng_py.randint(100, 900)) for _ in range(dimension)],
            'n_fac': dimension,
        }
    
    elif problem_name == 'SAN-1':
        # Calculate appropriate num_nodes for the number of edges (dimension)
        # For a DAG: we need num_nodes such that we can have 'dimension' edges
        # with a path from node 1 to num_nodes
        num_nodes = compute_num_nodes_for_dag(dimension)
        arcs = build_san_dag(num_nodes, dimension, rng=rng_py)
        return {
            'num_arcs': dimension,
            'num_nodes': num_nodes,
            'arcs': arcs,
            'arc_means': tuple(round(rng_py.uniform(1, 10), 2) for _ in range(dimension)),
        }
    
    elif problem_name == 'FIXEDSAN-1':
        num_nodes = max(2, rng_py.randint(2, max(2, dimension)))
        return {
            'num_arcs': dimension,
            'num_nodes': num_nodes,
            'arc_means': tuple(float(rng_py.randint(1, 10)) for _ in range(dimension)),
        }
    
    elif problem_name == 'ROSENBROCK-1':
        return {
            'x': (2.0,) * dimension,
            'variance': 0.4,
        }
    elif problem_name == 'ZAKHAROV-1':
        return {
            'x': (2.0,) * dimension,
            'variance': 0.1,
        }   
    
    elif problem_name == 'NETWORK-1':
        process_prob_elem = 1.0 / dimension
        mode_transit_time = [round(rng_py.uniform(0.01, 5), 3) for _ in range(dimension)]
        return {
            'process_prob': [process_prob_elem] * dimension,
            'cost_process': [0.1 / (x + 1) for x in range(dimension)],
            'cost_time': [round(rng_py.uniform(0.01, 1), 3) for _ in range(dimension)],
            'mode_transit_time': mode_transit_time,
            'lower_limits_transit_time': [x / 2 for x in mode_transit_time],
            'upper_limits_transit_time': [2 * x for x in mode_transit_time],
            'n_networks': dimension,
        }
    
    elif problem_name == 'CONTAM-2':
        return {
            'stages': dimension,
            'prev_decision': (0.0,) * dimension,
        }
    
    return {}


def get_scaled_problem_factors(problem_name: str, dimension: int) -> dict:
    """
    Generate problem factors scaled to the specified dimension.
    
    Only includes factors that will pass validation during construction.
    Factors that depend on model state are updated post-initialization.
    
    Args:
        problem_name: The abbreviated name of the problem
        dimension: The target dimension
        
    Returns:
        Dictionary of problem factors appropriate for the dimension
    """
    if problem_name == 'DYNAMNEWS-1':
        return {
            'initial_solution': (3.0,) * dimension,
        }
    
    elif problem_name in ('FACSIZE-1', 'FACSIZE-2'):
        # NOTE: installation_costs is validated against NUM_FACILITIES constant (=3)
        # So we can't pass it here - it will be updated post-initialization
        return {
            'initial_solution': (100.0,) * dimension,
            'installation_budget': 500.0 * (dimension / 3),  # Scale budget with dimension
        }
    
    elif problem_name in ('SAN-1', 'FIXEDSAN-1'):
        # NOTE: arc_costs is validated against NUM_ARCS constant (=13)
        # So we can't pass it here - it will be updated post-initialization
        return {
            'initial_solution': (1.0,) * dimension,
        }
    
    elif problem_name == 'ROSENBROCK-1':
        return {
            'initial_solution': (2.0,) * dimension,
        }
    
    elif problem_name == 'ZAKHAROV-1':
        return {
            'initial_solution': (2.0,) * dimension,
        }
    
    elif problem_name == 'NETWORK-1':
        return {
            'initial_solution': (1.0 / dimension,) * dimension,
        }
    
    elif problem_name == 'CONTAM-2':
        return {
            'initial_solution': (0.0,) * dimension,
        }
    
    return {}


def post_init_updates(problem: Problem, problem_name: str, dimension: int) -> None:
    """
    Update problem factors after initialization for factors that couldn't be set during construction.
    
    Some factors are validated against hardcoded constants during construction,
    so they need to be updated after the problem is instantiated.
    
    Args:
        problem: The problem instance to update
        problem_name: The abbreviated name of the problem
        dimension: The target dimension
    """
    if problem_name in ('FACSIZE-1', 'FACSIZE-2'):
        # Update installation_costs after construction to match the new dimension
        problem.factors['installation_costs'] = (1.0,) * dimension
    
    elif problem_name in ('SAN-1', 'FIXEDSAN-1'):
        # Update arc_costs after construction to match the new dimension
        # arc_costs is used in replicate(): np.sum(arc_costs / x)
        problem.factors['arc_costs'] = (1.0,) * dimension


def compute_num_nodes_for_dag(num_edges: int) -> int:
    """
    Compute an appropriate number of nodes for a DAG with the given number of edges.
    
    For a DAG with n nodes where we need a path from 1 to n:
    - Minimum edges needed: n-1 (a simple path)
    - Maximum edges possible: n*(n-1)/2 (complete DAG)
    
    We want to find the smallest n such that n*(n-1)/2 >= num_edges
    and n-1 <= num_edges (so we have enough edges for connectivity).
    
    Args:
        num_edges: Desired number of edges
        
    Returns:
        Number of nodes to use
    """
    # We need at least num_edges + 1 nodes in the worst case (simple path),
    # but we want fewer nodes with more edges between them.
    # Solve: n*(n-1)/2 >= num_edges => n^2 - n - 2*num_edges >= 0
    # n >= (1 + sqrt(1 + 8*num_edges)) / 2
    
    import math
    min_nodes = int(math.ceil((1 + math.sqrt(1 + 8 * num_edges)) / 2))
    
    # Ensure we have at least 2 nodes and the path is possible
    min_nodes = max(2, min_nodes)
    
    # Also ensure num_edges >= min_nodes - 1 (need at least a spanning path)
    # If not, we need more nodes
    while min_nodes - 1 > num_edges:
        min_nodes -= 1
    
    return min_nodes


def build_san_dag(num_nodes: int, num_edges: int, rng: random.Random | None = None) -> list[tuple[int, int]]:
    """
    Build a directed acyclic graph (DAG) suitable for the SAN model.
    
    The SAN model requires:
    1. Directed edges (arcs) from lower-numbered to higher-numbered nodes
    2. A path must exist from node 1 to node num_nodes
    3. Every node must be reachable from node 1 (for backtracking to work)
    
    This function first creates a simple sequential path from 1 to num_nodes
    (1→2→3→...→n), then adds additional random forward edges until reaching num_edges.
    
    Args:
        num_nodes: Number of nodes (numbered 1 to num_nodes)
        num_edges: Desired number of directed edges
        
    Returns:
        List of (source, target) tuples representing directed edges
        
    Raises:
        ValueError: If the requested configuration is impossible
    """
    min_edges = num_nodes - 1  # Simple path from 1 to num_nodes
    max_edges = num_nodes * (num_nodes - 1) // 2  # Complete DAG
    
    if num_edges < min_edges:
        raise ValueError(
            f"Cannot create DAG with path 1→{num_nodes}: need at least {min_edges} edges, "
            f"but only {num_edges} requested"
        )
    
    if num_edges > max_edges:
        raise ValueError(
            f"Cannot create DAG with {num_edges} edges: maximum possible is {max_edges} "
            f"for {num_nodes} nodes"
        )
    
    edges = set()
    
    # Step 1: Create a guaranteed SEQUENTIAL path from node 1 to node num_nodes
    # This ensures every node has a predecessor reachable from node 1
    # Path: 1 → 2 → 3 → ... → num_nodes
    for i in range(1, num_nodes):
        edges.add((i, i + 1))
    
    # Step 2: Add additional random forward edges until we reach num_edges
    if len(edges) < num_edges:
        if rng is None:
            rng = random
        # Generate all possible forward edges not yet in the graph
        all_possible_edges = []
        for i in range(1, num_nodes):
            for j in range(i + 1, num_nodes + 1):
                edge = (i, j)
                if edge not in edges:
                    all_possible_edges.append(edge)
        
        # Shuffle and add as many as needed
        rng.shuffle(all_possible_edges)
        edges_needed = num_edges - len(edges)
        
        for edge in all_possible_edges[:edges_needed]:
            edges.add(edge)
    
    return list(edges)


def validate_solver_and_problem_names(solver_name: str, problem_name: str) -> None:
    """Pre-flight validation for clearer errors before heavy work."""
    try:
        _ = instantiate_solver(solver_name=solver_name, fixed_factors={}, solver_rename=solver_name)
    except Exception as e:
        raise ValueError(f"Unknown or invalid solver code '{solver_name}'. Original error: {e}") from e

    try:
        _ = instantiate_problem(problem_name, problem_fixed_factors=None, model_fixed_factors=None)
    except Exception as e:
        raise ValueError(f"Unknown problem code '{problem_name}'. Original error: {e}") from e


def build_connected_graph(num_nodes: int, num_edges: int, rng: random.Random | None = None) -> list[tuple[int, int]]:
    """
    Build a connected graph with the specified number of nodes and edges.
    
    Starts with a spanning tree to ensure connectivity, then adds random edges
    until the desired number is reached.
    """
    if num_edges < num_nodes - 1:
        raise ValueError(f"Cannot create connected graph: need at least {num_nodes - 1} edges for {num_nodes} nodes")
    
    edges = set()
    
    if rng is None:
        rng = random

    # Create a spanning tree first to ensure connectivity
    nodes = list(range(num_nodes))
    rng.shuffle(nodes)
    for i in range(1, num_nodes):
        a = nodes[i]
        b = nodes[rng.randint(0, i - 1)]
        edges.add((min(a, b), max(a, b)))
    
    # Add random edges until we reach the desired number
    max_possible_edges = num_nodes * (num_nodes - 1) // 2
    target_edges = min(num_edges, max_possible_edges)
    
    attempts = 0
    max_attempts = target_edges * 10  # Prevent infinite loop
    while len(edges) < target_edges and attempts < max_attempts:
        a = rng.randint(0, num_nodes - 1)
        b = rng.randint(0, num_nodes - 1)
        if a != b:
            edges.add((min(a, b), max(a, b)))
        attempts += 1
    
    return list(edges)

# %%
# Determinism check: verify scaled model/problem factors are identical across repeated calls
# and do not vary by solver. This cell compares the outputs of the scaling helpers.

problems_to_check = problem_abbr_names
check_dim = 100

results = []
for pname in problems_to_check:
    if pname not in SCALABLE_PROBLEMS:
        results.append((pname, 'non-scalable', True, True))
        continue
    m1 = get_scaled_model_factors(pname, check_dim)
    p1 = get_scaled_problem_factors(pname, check_dim)
    model_ok = True
    prob_ok = True
    # Call the scaling helpers repeatedly and compare
    for _ in range(5):
        m2 = get_scaled_model_factors(pname, check_dim)
        p2 = get_scaled_problem_factors(pname, check_dim)
        if m1 != m2:
            model_ok = False
        if p1 != p2:
            prob_ok = False
    results.append((pname, check_dim, model_ok, prob_ok))

# Print a short summary
for r in results:
    print(f"{r[0]:15} dim={r[1]:>3} model_equal={r[2]} problem_equal={r[3]}")
# Out:
# SAN-1           dim=100 model_equal=True problem_equal=True
# NETWORK-1       dim=100 model_equal=True problem_equal=True
# DYNAMNEWS-1     dim=100 model_equal=True problem_equal=True
# ROSENBROCK-1    dim=100 model_equal=True problem_equal=True
# SSCONT-1        dim=non-scalable model_equal=True problem_equal=True

# %%
#Dictionary for different subspace sizes for each problem (only used for ASTROMORF)
subspace_sizes = {
    "NETWORK-1": 40,
    "ROSENBROCK-1": 40,
    "ZAKHAROV-1": 5,
    "SAN-1": 40,
    "FIXEDSAN-1": 9,
    "DYNAMNEWS-1": 40,
    "FACSIZE-1": 5,
    "FACSIZE-2": 5,
    "CONTAM-2": 20,
    "IRONORECONT-1": 2,
    "SSCONT-1": 1,
}

problems = [] 
for problem_name in problem_abbr_names:
    problem = scale_dimension(problem_name, 10000, 100)
    problems.append(problem)

#Construct a list of lists of ProblemSolver instances to be the experiments argument in the ProblemsSolvers constructor
experiments = []
for solver_name in solver_abbr_names:
    ps_same_solver = []
    for problem in problems:
        if solver_name == "ASTROMORF":
            if problem.name in ['SSCONT-1', 'IRONORECONT-1']:
                solver_factors = {'crn_across_solns': False, 'initial subspace dimension': subspace_sizes[problem.name], 'polynomial degree': 2}
            else :
                solver_factors = {'crn_across_solns': False, 'initial subspace dimension': subspace_sizes[problem.name]}
            solver_rename = "ASTROMoRF"
            solver = instantiate_solver(solver_name, solver_factors, solver_rename)
            print(f'ASTROMoRF has initial subspace: {solver.factors["initial subspace dimension"]} for problem {problem.name} with dimension {problem.dim}')
        else:
            solver_factors = {'crn_across_solns': False}
            if solver_name == "ASTRODF" :
                solver_rename = "ASTRO-DF"
            else : 
                solver_rename = solver_name
            solver = instantiate_solver(solver_name, solver_factors, solver_rename)
        ps_same_solver.append(ProblemSolver(
            solver = solver, 
            problem = problem
        ))
        # ps_same_solver.append(ProblemSolver(
        #     solver_name=solver_name,
        #     problem_name=problem_name,
        #     solver_fixed_factors=solver_factors,
        #     problem_fixed_factors={'budget': 10000}
        # )) 
    experiments.append(ps_same_solver)
# Out:
# ASTROMoRF has initial subspace: 40 for problem SAN-1 with dimension 100
# ASTROMoRF has initial subspace: 40 for problem NETWORK-1 with dimension 100
# ASTROMoRF has initial subspace: 40 for problem DYNAMNEWS-1 with dimension 100
# ASTROMoRF has initial subspace: 40 for problem ROSENBROCK-1 with dimension 100
# ASTROMoRF has initial subspace: 1 for problem SSCONT-1 with dimension 2

# %%
# Initialize an instance of the experiment class.
from simopt.experiment_base import ProblemsSolvers


mymetaexperiment = ProblemsSolvers(
    experiments=experiments
)

# Write to log file.
mymetaexperiment.log_group_experiment_results()

# %%
# Enable logging and show per-experiment complexity estimates
import logging

# Configure logging so we see which pair is currently running
logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s | %(message)s")
print("Logging set to INFO. You will see per-pair progress as they start/finish.")
# Out:
# Logging set to INFO. You will see per-pair progress as they start/finish.

# %%
# Run a fixed number of macroreplications of each solver on each problem.
mymetaexperiment.run(n_macroreps=num_macroreps)
# Out:
# 2026-01-23 01:03:42,296 | INFO | Running solver ASTROMoRF on problem SAN-1.
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# 2026-01-23 01:04:59,998 | INFO | Finished running 5 mreps in 77.702 seconds.
# 2026-01-23 01:05:00,004 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_SAN-1.pickle
# 2026-01-23 01:05:00,004 | INFO | Running solver ASTROMoRF on problem NETWORK-1.
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# 2026-01-23 01:06:28,595 | INFO | Finished running 5 mreps in 88.591 seconds.
# 2026-01-23 01:06:28,599 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_NETWORK-1.pickle
# 2026-01-23 01:06:28,600 | INFO | Running solver ASTROMoRF on problem DYNAMNEWS-1.
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# Iteration 6: Adaptive subspace dimension change: 38 -> 36
# 2026-01-23 01:08:02,554 | INFO | Finished running 5 mreps in 93.955 seconds.
# 2026-01-23 01:08:02,558 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:08:02,559 | INFO | Running solver ASTROMoRF on problem ROSENBROCK-1.
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# Iteration 3: Adaptive subspace dimension change: 40 -> 38
# 2026-01-23 01:09:24,165 | INFO | Finished running 5 mreps in 81.607 seconds.
# 2026-01-23 01:09:24,169 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_ROSENBROCK-1.pickle
# 2026-01-23 01:09:24,169 | INFO | Running solver ASTROMoRF on problem SSCONT-1.
# 2026-01-23 01:09:56,624 | INFO | Finished running 5 mreps in 32.455 seconds.
# 2026-01-23 01:09:56,630 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_SSCONT-1.pickle
# 2026-01-23 01:09:56,630 | INFO | Running solver ADAM on problem SAN-1.
# 2026-01-23 01:09:57,939 | INFO | Finished running 5 mreps in 1.309 seconds.
# 2026-01-23 01:09:57,944 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_SAN-1.pickle
# 2026-01-23 01:09:57,944 | INFO | Running solver ADAM on problem NETWORK-1.
# 2026-01-23 01:10:22,273 | INFO | Finished running 5 mreps in 24.329 seconds.
# 2026-01-23 01:10:22,277 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_NETWORK-1.pickle
# 2026-01-23 01:10:22,277 | INFO | Running solver ADAM on problem DYNAMNEWS-1.
# 2026-01-23 01:10:40,062 | INFO | Finished running 5 mreps in 17.785 seconds.
# 2026-01-23 01:10:40,066 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:10:40,066 | INFO | Running solver ADAM on problem ROSENBROCK-1.
# 2026-01-23 01:10:40,901 | INFO | Finished running 5 mreps in 0.834 seconds.
# 2026-01-23 01:10:40,905 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_ROSENBROCK-1.pickle
# 2026-01-23 01:10:40,905 | INFO | Running solver ADAM on problem SSCONT-1.
# 2026-01-23 01:10:44,402 | INFO | Finished running 5 mreps in 3.497 seconds.
# 2026-01-23 01:10:44,406 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_SSCONT-1.pickle
# 2026-01-23 01:10:44,407 | INFO | Running solver NELDMD on problem SAN-1.
# 2026-01-23 01:10:46,674 | INFO | Finished running 5 mreps in 2.267 seconds.
# 2026-01-23 01:10:46,678 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_SAN-1.pickle
# 2026-01-23 01:10:46,679 | INFO | Running solver NELDMD on problem NETWORK-1.
# 2026-01-23 01:11:24,036 | INFO | Finished running 5 mreps in 37.357 seconds.
# 2026-01-23 01:11:24,040 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_NETWORK-1.pickle
# 2026-01-23 01:11:24,041 | INFO | Running solver NELDMD on problem DYNAMNEWS-1.
# 2026-01-23 01:11:54,182 | INFO | Finished running 5 mreps in 30.141 seconds.
# 2026-01-23 01:11:54,185 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:11:54,186 | INFO | Running solver NELDMD on problem ROSENBROCK-1.
# 2026-01-23 01:11:55,598 | INFO | Finished running 5 mreps in 1.412 seconds.
# 2026-01-23 01:11:55,601 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_ROSENBROCK-1.pickle
# 2026-01-23 01:11:55,602 | INFO | Running solver NELDMD on problem SSCONT-1.
# 2026-01-23 01:12:00,827 | INFO | Finished running 5 mreps in 5.226 seconds.
# 2026-01-23 01:12:00,832 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_SSCONT-1.pickle
# 2026-01-23 01:12:00,832 | INFO | Running solver RNDSRCH on problem SAN-1.
# 2026-01-23 01:12:03,302 | INFO | Finished running 5 mreps in 2.470 seconds.
# 2026-01-23 01:12:03,307 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_SAN-1.pickle
# 2026-01-23 01:12:03,307 | INFO | Running solver RNDSRCH on problem NETWORK-1.
# 2026-01-23 01:12:42,442 | INFO | Finished running 5 mreps in 39.135 seconds.
# 2026-01-23 01:12:42,451 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_NETWORK-1.pickle
# 2026-01-23 01:12:42,451 | INFO | Running solver RNDSRCH on problem DYNAMNEWS-1.
# 2026-01-23 01:13:12,835 | INFO | Finished running 5 mreps in 30.384 seconds.
# 2026-01-23 01:13:12,839 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:13:12,839 | INFO | Running solver RNDSRCH on problem ROSENBROCK-1.
# 2026-01-23 01:13:14,689 | INFO | Finished running 5 mreps in 1.849 seconds.
# 2026-01-23 01:13:14,696 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_ROSENBROCK-1.pickle
# 2026-01-23 01:13:14,697 | INFO | Running solver RNDSRCH on problem SSCONT-1.
# 2026-01-23 01:13:18,919 | INFO | Finished running 5 mreps in 4.222 seconds.
# 2026-01-23 01:13:18,923 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_SSCONT-1.pickle
# 2026-01-23 01:13:18,924 | INFO | Running solver STRONG on problem SAN-1.
# 2026-01-23 01:13:21,783 | INFO | Finished running 5 mreps in 2.859 seconds.
# 2026-01-23 01:13:21,787 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_SAN-1.pickle
# 2026-01-23 01:13:21,787 | INFO | Running solver STRONG on problem NETWORK-1.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# WARNING:root:r_diff (stage I) is 0.0. Setting to 1e-15 to avoid division by zero.
# 2026-01-23 01:14:09,009 | INFO | Finished running 5 mreps in 47.222 seconds.
# 2026-01-23 01:14:09,013 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_NETWORK-1.pickle
# 2026-01-23 01:14:09,013 | INFO | Running solver STRONG on problem DYNAMNEWS-1.
# 2026-01-23 01:14:46,350 | INFO | Finished running 5 mreps in 37.336 seconds.
# 2026-01-23 01:14:46,355 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:14:46,355 | INFO | Running solver STRONG on problem ROSENBROCK-1.
# 2026-01-23 01:14:48,013 | INFO | Finished running 5 mreps in 1.658 seconds.
# 2026-01-23 01:14:48,017 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_ROSENBROCK-1.pickle
# 2026-01-23 01:14:48,017 | INFO | Running solver STRONG on problem SSCONT-1.
# 2026-01-23 01:15:04,033 | INFO | Finished running 5 mreps in 16.016 seconds.
# 2026-01-23 01:15:04,037 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_SSCONT-1.pickle
# 2026-01-23 01:15:04,037 | INFO | Running solver ASTRO-DF on problem SAN-1.
# 2026-01-23 01:15:29,522 | INFO | Finished running 5 mreps in 25.485 seconds.
# 2026-01-23 01:15:29,526 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_SAN-1.pickle
# 2026-01-23 01:15:29,526 | INFO | Running solver ASTRO-DF on problem NETWORK-1.
# 2026-01-23 01:16:19,122 | INFO | Finished running 5 mreps in 49.596 seconds.
# 2026-01-23 01:16:19,126 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_NETWORK-1.pickle
# 2026-01-23 01:16:19,127 | INFO | Running solver ASTRO-DF on problem DYNAMNEWS-1.
# 2026-01-23 01:16:59,620 | INFO | Finished running 5 mreps in 40.494 seconds.
# 2026-01-23 01:16:59,624 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:16:59,624 | INFO | Running solver ASTRO-DF on problem ROSENBROCK-1.
# 2026-01-23 01:17:30,155 | INFO | Finished running 5 mreps in 30.531 seconds.
# 2026-01-23 01:17:30,161 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:30,162 | INFO | Running solver ASTRO-DF on problem SSCONT-1.
# 2026-01-23 01:17:35,415 | INFO | Finished running 5 mreps in 5.253 seconds.
# 2026-01-23 01:17:35,419 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_SSCONT-1.pickle

# %%
print("Post-processing results.")
# Run a fixed number of postreplications at all recommended solutions.
mymetaexperiment.post_replicate(n_postreps=num_postreps)
# Out:
# 2026-01-23 01:17:35,446 | INFO | Starting postreplications
# 2026-01-23 01:17:35,511 | INFO | Finished running 5 postreplications in 0.065 seconds.
# 2026-01-23 01:17:35,513 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_SAN-1.pickle
# 2026-01-23 01:17:35,514 | INFO | Starting postreplications
# Post-processing results.
# 2026-01-23 01:17:36,326 | INFO | Finished running 5 postreplications in 0.813 seconds.
# 2026-01-23 01:17:36,330 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_NETWORK-1.pickle
# 2026-01-23 01:17:36,330 | INFO | Starting postreplications
# 2026-01-23 01:17:37,184 | INFO | Finished running 5 postreplications in 0.854 seconds.
# 2026-01-23 01:17:37,190 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:17:37,190 | INFO | Starting postreplications
# 2026-01-23 01:17:37,228 | INFO | Finished running 5 postreplications in 0.037 seconds.
# 2026-01-23 01:17:37,230 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:37,231 | INFO | Starting postreplications
# 2026-01-23 01:17:37,387 | INFO | Finished running 5 postreplications in 0.156 seconds.
# 2026-01-23 01:17:37,390 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTROMoRF_on_SSCONT-1.pickle
# 2026-01-23 01:17:37,391 | INFO | Starting postreplications
# 2026-01-23 01:17:37,461 | INFO | Finished running 5 postreplications in 0.071 seconds.
# 2026-01-23 01:17:37,466 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_SAN-1.pickle
# 2026-01-23 01:17:37,467 | INFO | Starting postreplications
# 2026-01-23 01:17:37,839 | INFO | Finished running 5 postreplications in 0.373 seconds.
# 2026-01-23 01:17:37,842 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_NETWORK-1.pickle
# 2026-01-23 01:17:37,842 | INFO | Starting postreplications
# 2026-01-23 01:17:38,129 | INFO | Finished running 5 postreplications in 0.287 seconds.
# 2026-01-23 01:17:38,132 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:17:38,133 | INFO | Starting postreplications
# 2026-01-23 01:17:38,157 | INFO | Finished running 5 postreplications in 0.024 seconds.
# 2026-01-23 01:17:38,159 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:38,159 | INFO | Starting postreplications
# 2026-01-23 01:17:38,280 | INFO | Finished running 5 postreplications in 0.121 seconds.
# 2026-01-23 01:17:38,284 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ADAM_on_SSCONT-1.pickle
# 2026-01-23 01:17:38,284 | INFO | Starting postreplications
# 2026-01-23 01:17:38,321 | INFO | Finished running 5 postreplications in 0.037 seconds.
# 2026-01-23 01:17:38,324 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_SAN-1.pickle
# 2026-01-23 01:17:38,324 | INFO | Starting postreplications
# 2026-01-23 01:17:38,587 | INFO | Finished running 5 postreplications in 0.263 seconds.
# 2026-01-23 01:17:38,589 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_NETWORK-1.pickle
# 2026-01-23 01:17:38,589 | INFO | Starting postreplications
# 2026-01-23 01:17:38,785 | INFO | Finished running 5 postreplications in 0.196 seconds.
# 2026-01-23 01:17:38,786 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:17:38,786 | INFO | Starting postreplications
# 2026-01-23 01:17:38,812 | INFO | Finished running 5 postreplications in 0.025 seconds.
# 2026-01-23 01:17:38,815 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:38,816 | INFO | Starting postreplications
# 2026-01-23 01:17:39,546 | INFO | Finished running 5 postreplications in 0.73 seconds.
# 2026-01-23 01:17:39,552 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/NELDMD_on_SSCONT-1.pickle
# 2026-01-23 01:17:39,553 | INFO | Starting postreplications
# 2026-01-23 01:17:39,579 | INFO | Finished running 5 postreplications in 0.026 seconds.
# 2026-01-23 01:17:39,581 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_SAN-1.pickle
# 2026-01-23 01:17:39,581 | INFO | Starting postreplications
# 2026-01-23 01:17:41,221 | INFO | Finished running 5 postreplications in 1.64 seconds.
# 2026-01-23 01:17:41,229 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_NETWORK-1.pickle
# 2026-01-23 01:17:41,229 | INFO | Starting postreplications
# 2026-01-23 01:17:41,434 | INFO | Finished running 5 postreplications in 0.205 seconds.
# 2026-01-23 01:17:41,436 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:17:41,436 | INFO | Starting postreplications
# 2026-01-23 01:17:41,509 | INFO | Finished running 5 postreplications in 0.073 seconds.
# 2026-01-23 01:17:41,516 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:41,516 | INFO | Starting postreplications
# 2026-01-23 01:17:41,663 | INFO | Finished running 5 postreplications in 0.147 seconds.
# 2026-01-23 01:17:41,667 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/RNDSRCH_on_SSCONT-1.pickle
# 2026-01-23 01:17:41,667 | INFO | Starting postreplications
# 2026-01-23 01:17:41,706 | INFO | Finished running 5 postreplications in 0.039 seconds.
# 2026-01-23 01:17:41,709 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_SAN-1.pickle
# 2026-01-23 01:17:41,709 | INFO | Starting postreplications
# 2026-01-23 01:17:42,439 | INFO | Finished running 5 postreplications in 0.73 seconds.
# 2026-01-23 01:17:42,444 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_NETWORK-1.pickle
# 2026-01-23 01:17:42,444 | INFO | Starting postreplications
# 2026-01-23 01:17:43,056 | INFO | Finished running 5 postreplications in 0.612 seconds.
# 2026-01-23 01:17:43,062 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:17:43,062 | INFO | Starting postreplications
# 2026-01-23 01:17:43,101 | INFO | Finished running 5 postreplications in 0.039 seconds.
# 2026-01-23 01:17:43,105 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:43,106 | INFO | Starting postreplications
# 2026-01-23 01:17:43,178 | INFO | Finished running 5 postreplications in 0.072 seconds.
# 2026-01-23 01:17:43,180 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/STRONG_on_SSCONT-1.pickle
# 2026-01-23 01:17:43,180 | INFO | Starting postreplications
# 2026-01-23 01:17:43,205 | INFO | Finished running 5 postreplications in 0.025 seconds.
# 2026-01-23 01:17:43,207 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_SAN-1.pickle
# 2026-01-23 01:17:43,207 | INFO | Starting postreplications
# 2026-01-23 01:17:43,500 | INFO | Finished running 5 postreplications in 0.293 seconds.
# 2026-01-23 01:17:43,502 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_NETWORK-1.pickle
# 2026-01-23 01:17:43,503 | INFO | Starting postreplications
# 2026-01-23 01:17:43,815 | INFO | Finished running 5 postreplications in 0.312 seconds.
# 2026-01-23 01:17:43,816 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_DYNAMNEWS-1.pickle
# 2026-01-23 01:17:43,817 | INFO | Starting postreplications
# 2026-01-23 01:17:43,843 | INFO | Finished running 5 postreplications in 0.026 seconds.
# 2026-01-23 01:17:43,845 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_ROSENBROCK-1.pickle
# 2026-01-23 01:17:43,845 | INFO | Starting postreplications
# 2026-01-23 01:17:44,041 | INFO | Finished running 5 postreplications in 0.196 seconds.
# 2026-01-23 01:17:44,044 | INFO | Saved experiment results to /Users/benjaminrees/Desktop/simopt/notebooks/experiments/2026-01-23_01-03-42/ASTRO-DF_on_SSCONT-1.pickle

# %%
print("Post-normalizing results.")

# Find an optimal solution x* for normalization.
mymetaexperiment.post_normalize(n_postreps_init_opt=num_postreps_init_opt)
# Out:
# 2026-01-23 01:17:44,090 | INFO | Postnormalizing on Problem SAN-1.
# 2026-01-23 01:17:44,097 | INFO | Global proxy x* computed for problem SAN-1.
# 2026-01-23 01:17:44,098 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,105 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,112 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,119 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,126 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,133 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,140 | INFO | Postnormalizing on Problem NETWORK-1.
# 2026-01-23 01:17:44,256 | INFO | Global proxy x* computed for problem NETWORK-1.
# 2026-01-23 01:17:44,256 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# Post-normalizing results.
# 2026-01-23 01:17:44,371 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,487 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,603 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,715 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,827 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:44,937 | INFO | Postnormalizing on Problem DYNAMNEWS-1.
# 2026-01-23 01:17:45,026 | INFO | Global proxy x* computed for problem DYNAMNEWS-1.
# 2026-01-23 01:17:45,026 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,114 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,201 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,289 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,378 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,489 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,581 | INFO | Postnormalizing on Problem ROSENBROCK-1.
# 2026-01-23 01:17:45,582 | INFO | Finding f(x*) using coded f(x*).
# 2026-01-23 01:17:45,587 | INFO | Finding f(x*) using coded f(x*).
# 2026-01-23 01:17:45,591 | INFO | Finding f(x*) using coded f(x*).
# 2026-01-23 01:17:45,596 | INFO | Finding f(x*) using coded f(x*).
# 2026-01-23 01:17:45,601 | INFO | Finding f(x*) using coded f(x*).
# 2026-01-23 01:17:45,605 | INFO | Finding f(x*) using coded f(x*).
# 2026-01-23 01:17:45,610 | INFO | Postnormalizing on Problem SSCONT-1.
# 2026-01-23 01:17:45,626 | INFO | Global proxy x* computed for problem SSCONT-1.
# 2026-01-23 01:17:45,626 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,638 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,649 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,661 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,673 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.
# 2026-01-23 01:17:45,685 | INFO | Finding f(x*) using using global best postreplicated solution as proxy for x*.

# %%
# Produce basic plots.
import matplotlib.pyplot as plt
from IPython.display import Image, display

from simopt.experiment_base import PlotType, plot_solvability_profiles, plot_budget_history, plot_fn_estimates, plot_progress_curves

print("Plotting results...")

ps_same_problem_dict = {}
# take the experiments of mymetaexperiment and create a list of lists from ps_same_problem_list where each sublist contains all solvers for a given problem
experiments_flattened = [ps for solver_experiments in mymetaexperiment.experiments for ps in solver_experiments]
for exp in experiments_flattened:
    if exp.problem.name not in ps_same_problem_dict:
        ps_same_problem_dict[exp.problem.name] = []
    ps_same_problem_dict[exp.problem.name].append(exp)

#turn the items of ps_same_problem_dict into a list of lists
experiments_flattened = []
for problem_name, ps_list in ps_same_problem_dict.items():
    experiments_flattened.append(ps_list)








def _print_path_and_display(plot_paths: list[Path]) -> None:
    for plot_path in plot_paths:
        print(f"Plot saved to {plot_path!s}")
        display(Image(filename=str(plot_path)))


_print_path_and_display(
    plot_solvability_profiles(
        experiments=mymetaexperiment.experiments, plot_type=PlotType.CDF_SOLVABILITY
    )
)


for problem in experiments_flattened:
    _print_path_and_display(
        plot_progress_curves(
            experiments=problem, 
            plot_type=PlotType.MEAN, 
            solver_set_name="ASTRO-DF and ASTROMoRF", 
            normalize=True,
            allow_xstar_mismatch=True
        )
    )

# mymetaexperiment.experiments is structured as experiments[solver_idx][problem_idx]
# To plot all solvers for each problem, we need to transpose the structure
n_solvers = len(mymetaexperiment.experiments)
n_problems = len(mymetaexperiment.experiments[0]) if n_solvers > 0 else 0

for prob_idx in range(n_problems):
    # Collect all solvers for this problem
    solvers_for_problem = [mymetaexperiment.experiments[solver_idx][prob_idx] for solver_idx in range(n_solvers)]

    #get the terminal budget for each problem solver 
    [print(f"solver {s.solver.name} on problem {s.problem.name} has budget {[x[-1] for x in s.all_budget_history]}") for s in solvers_for_problem]

    _print_path_and_display(
        plot_fn_estimates(
            experiments=solvers_for_problem,
            plot_type=PlotType.FN_ESTIMATES_MEAN, 
            solver_set_name="ASTRO-DF and ASTROMoRF", 
            normalize=True,
        )
    )
    _print_path_and_display(
        plot_budget_history(
            experiments=solvers_for_problem,
            plot_type=PlotType.BUDGET_HISTORY_MEAN, 
            solver_set_name="ASTRO-DF and ASTROMoRF", 
            normalize=True
        )
    )

print("Plotting complete!")
# Out:
# Plotting results...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 36
#      31         print(f"Plot saved to {plot_path!s}")
#      32         display(Image(filename=str(plot_path)))
#      35 _print_path_and_display(
# ---> 36     plot_solvability_profiles(
#      37         experiments=mymetaexperiment.experiments, plot_type=PlotType.CDF_SOLVABILITY
#      38     )
#      39 )
#      42 for problem in experiments_flattened:
#      43     _print_path_and_display(
#      44         plot_progress_curves(
#      45             experiments=problem,
#    (...)     50         )
#      51     )
#
# File ~/Desktop/simopt/simopt/plots/solvability_profile.py:179, in plot_solvability_profiles(experiments, plot_type, all_in_one, n_bootstraps, conf_level, plot_conf_ints, print_max_hw, solve_tol, beta, ref_solver, plot_title, legend_loc, ext, save_as_pickle, solver_set_name, problem_set_name)
#     177 solver_curve_handles.append(handle)
#     178 if plot_conf_ints or print_max_hw:
# --> 179     bs_conf_int_lb_curve, bs_conf_int_ub_curve = bootstrap_procedure(
#     180         experiments=[experiments[solver_idx]],
#     181         n_bootstraps=n_bootstraps,
#     182         conf_level=conf_level,
#     183         plot_type=plot_type,  # type: ignore
#     184         solve_tol=solve_tol,
#     185         beta=beta,
#     186         estimator=solver_curve,
#     187         normalize=True,
#     188     )
#     189     if plot_conf_ints:
#     190         if isinstance(bs_conf_int_lb_curve, (int, float)) or isinstance(
#     191             bs_conf_int_ub_curve, (int, float)
#     192         ):
#
# File ~/Desktop/simopt/simopt/bootstrap.py:232, in bootstrap_procedure(experiments, n_bootstraps, conf_level, plot_type, beta, solve_tol, estimator, normalize, feasibility_score_method, feasibility_norm_degree, feasibility_two_sided)
#     229 # Create the curves for the lower and upper bounds of the bootstrap
#     230 # confidence intervals.
#     231 unique_budget_list_floats = [float(val) for val in unique_budget_list]
# --> 232 lower_bound_list = [float(val) for val in bs_conf_int_lower_bound_list]
#     233 bs_conf_int_lower_bounds = Curve(
#     234     x_vals=unique_budget_list_floats, y_vals=lower_bound_list
#     235 )
#     236 upper_bound_list = [float(val) for val in bs_conf_int_upper_bound_list]
#
# TypeError: only 0-dimensional arrays can be converted to Python scalars

# %%
# Analyze budget per iteration for both solvers
print("=" * 80)
print("BUDGET ANALYSIS: ASTROMoRF vs ASTRO-DF")
print("=" * 80)

#flatten the experiments list into a single list
flatten_experiments = []
for solver_experiments in mymetaexperiment.experiments:
    for experiment in solver_experiments:
        flatten_experiments.append(experiment)

#in the flatten experiments list place common problems together
flatten_experiments.sort(key=lambda e: (e.problem.name, e.solver.name))

for experiment in flatten_experiments:
    solver_name = experiment.solver.name
    problem_name = experiment.problem.name
    problem_dim = experiment.problem.dim
    if solver_name.upper() == "ASTROMORF":
        subspace_dim = experiment.solver.factors.get('initial subspace dimension', 4)
    
    print(f"\n{solver_name} on {problem_name} (dim={problem_dim}):")
    print("-" * 60)
    
    for macrorep in range(experiment.n_macroreps):
        budgets = experiment.all_intermediate_budgets[macrorep]
        n_iters = len(budgets)
        
        if n_iters > 1:
            # Calculate budget spent per iteration
            budget_per_iter = [budgets[0]]  # First iteration
            for i in range(1, n_iters):
                budget_per_iter.append(budgets[i] - budgets[i-1])
            
            avg_budget_per_iter = sum(budget_per_iter) / len(budget_per_iter)
            max_budget_iter = max(budget_per_iter)
            total_budget = budgets[-1]
            
            print(f"  Macrorep {macrorep + 1}:")
            print(f"    Total iterations: {n_iters}")
            print(f"    Total budget used: {total_budget}")
            print(f"    Avg budget/iteration: {avg_budget_per_iter:.1f}")
            print(f"    Max budget in single iteration: {max_budget_iter}")
            
            # Expected design points per iteration
            if "ASTROMORF" in solver_name.upper():
                # ASTROMoRF uses 2d+1 where d is subspace dimension (default 4)
                expected_points = 2 * subspace_dim + 1
                print(f"    Expected design points/iter (2*{subspace_dim}+1): {expected_points}")
            else:  # ASTRO-DF
                expected_points = 2 * problem_dim + 1
                print(f"    Expected design points/iter (2*{problem_dim}+1): {expected_points}")
            
            print(f"    Implied avg samples/point: {avg_budget_per_iter / expected_points:.1f}")
# Out:
# ================================================================================
# BUDGET ANALYSIS: ASTROMoRF vs ASTRO-DF
# ================================================================================
#
# ADAM on DYNAMNEWS-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 31.1
#   Macrorep 2:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 31.1
#   Macrorep 3:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 31.1
#   Macrorep 4:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 31.1
#   Macrorep 5:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 31.1
#
# ASTRO-DF on DYNAMNEWS-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 9849
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 2:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 9849
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 3:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 9849
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 4:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 9849
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 5:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 9849
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#
# ASTROMoRF on DYNAMNEWS-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 48231
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 61.7
#   Macrorep 2:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 48285
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 61.7
#   Macrorep 3:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 48340
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 61.7
#   Macrorep 4:
#     Total iterations: 12
#     Total budget used: 50000
#     Avg budget/iteration: 4166.7
#     Max budget in single iteration: 48242
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 51.4
#   Macrorep 5:
#     Total iterations: 31
#     Total budget used: 50000
#     Avg budget/iteration: 1612.9
#     Max budget in single iteration: 47680
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 19.9
#
# NELDMD on DYNAMNEWS-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 29720
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 2:
#     Total iterations: 19
#     Total budget used: 50000
#     Avg budget/iteration: 2631.6
#     Max budget in single iteration: 9870
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 13.1
#   Macrorep 3:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 20870
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 27.6
#   Macrorep 4:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 34040
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 5:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 26510
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#
# RNDSRCH on DYNAMNEWS-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 2:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 3:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 4:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 5:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#
# STRONG on DYNAMNEWS-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 4623
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 15.5
#   Macrorep 2:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 4623
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 15.5
#   Macrorep 3:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 4623
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 15.5
#   Macrorep 4:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 4623
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 15.5
#   Macrorep 5:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 4623
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 15.5
#
# ADAM on NETWORK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 35280
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 2:
#     Total iterations: 11
#     Total budget used: 50000
#     Avg budget/iteration: 4545.5
#     Max budget in single iteration: 17130
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 22.6
#   Macrorep 3:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 32460
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 4:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 23100
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 24.9
#   Macrorep 5:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 26550
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 31.1
#
# ASTRO-DF on NETWORK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 25139
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 2:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 25231
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 3:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 25284
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 4:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 24850
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 5:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 14927
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#
# ASTROMoRF on NETWORK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 13
#     Total budget used: 50000
#     Avg budget/iteration: 3846.2
#     Max budget in single iteration: 40832
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 47.5
#   Macrorep 2:
#     Total iterations: 13
#     Total budget used: 50000
#     Avg budget/iteration: 3846.2
#     Max budget in single iteration: 31213
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 47.5
#   Macrorep 3:
#     Total iterations: 23
#     Total budget used: 50000
#     Avg budget/iteration: 2173.9
#     Max budget in single iteration: 27176
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 26.8
#   Macrorep 4:
#     Total iterations: 13
#     Total budget used: 50000
#     Avg budget/iteration: 3846.2
#     Max budget in single iteration: 40737
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 47.5
#   Macrorep 5:
#     Total iterations: 12
#     Total budget used: 50000
#     Avg budget/iteration: 4166.7
#     Max budget in single iteration: 30422
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 51.4
#
# NELDMD on NETWORK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 23
#     Total budget used: 50000
#     Avg budget/iteration: 2173.9
#     Max budget in single iteration: 12090
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 10.8
#   Macrorep 2:
#     Total iterations: 22
#     Total budget used: 50000
#     Avg budget/iteration: 2272.7
#     Max budget in single iteration: 13440
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 11.3
#   Macrorep 3:
#     Total iterations: 20
#     Total budget used: 50000
#     Avg budget/iteration: 2500.0
#     Max budget in single iteration: 12060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 12.4
#   Macrorep 4:
#     Total iterations: 26
#     Total budget used: 50000
#     Avg budget/iteration: 1923.1
#     Max budget in single iteration: 13770
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 9.6
#   Macrorep 5:
#     Total iterations: 21
#     Total budget used: 50000
#     Avg budget/iteration: 2381.0
#     Max budget in single iteration: 12870
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 11.8
#
# RNDSRCH on NETWORK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 15
#     Total budget used: 50000
#     Avg budget/iteration: 3333.3
#     Max budget in single iteration: 19320
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 16.6
#   Macrorep 2:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 48890
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 24.9
#   Macrorep 3:
#     Total iterations: 13
#     Total budget used: 50000
#     Avg budget/iteration: 3846.2
#     Max budget in single iteration: 23960
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 19.1
#   Macrorep 4:
#     Total iterations: 11
#     Total budget used: 50000
#     Avg budget/iteration: 4545.5
#     Max budget in single iteration: 48910
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 22.6
#   Macrorep 5:
#     Total iterations: 12
#     Total budget used: 50000
#     Avg budget/iteration: 4166.7
#     Max budget in single iteration: 37590
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 20.7
#
# STRONG on NETWORK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 24780
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 49.8
#   Macrorep 2:
#     Total iterations: 3
#     Total budget used: 50000
#     Avg budget/iteration: 16666.7
#     Max budget in single iteration: 47980
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 82.9
#   Macrorep 3:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 40780
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 4:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 45780
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 5:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 34980
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#
# ADAM on ROSENBROCK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 2:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 3:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 4:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 5:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#
# ASTRO-DF on ROSENBROCK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 3
#     Total budget used: 50000
#     Avg budget/iteration: 16666.7
#     Max budget in single iteration: 40102
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 82.9
#   Macrorep 2:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 19600
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 49.8
#   Macrorep 3:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 19600
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 49.8
#   Macrorep 4:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 20502
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 5:
#     Total iterations: 3
#     Total budget used: 50000
#     Avg budget/iteration: 16666.7
#     Max budget in single iteration: 40102
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 82.9
#
# ASTROMoRF on ROSENBROCK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 83
#     Total budget used: 50000
#     Avg budget/iteration: 602.4
#     Max budget in single iteration: 6895
#     Expected design points/iter (2*70+1): 141
#     Implied avg samples/point: 4.3
#   Macrorep 2:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 43763
#     Expected design points/iter (2*70+1): 141
#     Implied avg samples/point: 88.7
#   Macrorep 3:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 24739
#     Expected design points/iter (2*70+1): 141
#     Implied avg samples/point: 35.5
#   Macrorep 4:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 43982
#     Expected design points/iter (2*70+1): 141
#     Implied avg samples/point: 88.7
#   Macrorep 5:
#     Total iterations: 17
#     Total budget used: 50000
#     Avg budget/iteration: 2941.2
#     Max budget in single iteration: 13194
#     Expected design points/iter (2*70+1): 141
#     Implied avg samples/point: 20.9
#
# NELDMD on ROSENBROCK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 46970
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 2:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 46970
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 3:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 46970
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 4:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 46970
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 5:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 46970
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#
# RNDSRCH on ROSENBROCK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 24230
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 27.6
#   Macrorep 2:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 35160
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 24.9
#   Macrorep 3:
#     Total iterations: 13
#     Total budget used: 50000
#     Avg budget/iteration: 3846.2
#     Max budget in single iteration: 30790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 19.1
#   Macrorep 4:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 37770
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 5:
#     Total iterations: 14
#     Total budget used: 50000
#     Avg budget/iteration: 3571.4
#     Max budget in single iteration: 30260
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 17.8
#
# STRONG on ROSENBROCK-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 11
#     Total budget used: 50000
#     Avg budget/iteration: 4545.5
#     Max budget in single iteration: 20845
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 22.6
#   Macrorep 2:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 37930
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 3:
#     Total iterations: 3
#     Total budget used: 50000
#     Avg budget/iteration: 16666.7
#     Max budget in single iteration: 47980
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 82.9
#   Macrorep 4:
#     Total iterations: 11
#     Total budget used: 50000
#     Avg budget/iteration: 4545.5
#     Max budget in single iteration: 12604
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 22.6
#   Macrorep 5:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 20845
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 24.9
#
# ADAM on SAN-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 6060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 24.9
#   Macrorep 2:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 25850
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 3:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 4:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#   Macrorep 5:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 13790
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 35.5
#
# ASTRO-DF on SAN-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 19698
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 2:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 19698
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 3:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 19698
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 4:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 19698
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#   Macrorep 5:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 19698
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 41.5
#
# ASTROMoRF on SAN-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 26524
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 61.7
#   Macrorep 2:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 43745
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 88.2
#   Macrorep 3:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 33674
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 77.2
#   Macrorep 4:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 22335
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 38.6
#   Macrorep 5:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 32178
#     Expected design points/iter (2*40+1): 81
#     Implied avg samples/point: 68.6
#
# NELDMD on SAN-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 21
#     Total budget used: 50000
#     Avg budget/iteration: 2381.0
#     Max budget in single iteration: 15060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 11.8
#   Macrorep 2:
#     Total iterations: 21
#     Total budget used: 50000
#     Avg budget/iteration: 2381.0
#     Max budget in single iteration: 18060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 11.8
#   Macrorep 3:
#     Total iterations: 21
#     Total budget used: 50000
#     Avg budget/iteration: 2381.0
#     Max budget in single iteration: 18060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 11.8
#   Macrorep 4:
#     Total iterations: 25
#     Total budget used: 50000
#     Avg budget/iteration: 2000.0
#     Max budget in single iteration: 15060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 10.0
#   Macrorep 5:
#     Total iterations: 26
#     Total budget used: 50000
#     Avg budget/iteration: 1923.1
#     Max budget in single iteration: 15060
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 9.6
#
# RNDSRCH on SAN-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 2:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 3:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 4:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#   Macrorep 5:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 50000
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 124.4
#
# STRONG on SAN-1 (dim=100):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 45769
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 2:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 34915
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 49.8
#   Macrorep 3:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 34915
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 49.8
#   Macrorep 4:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 43357
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#   Macrorep 5:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 45769
#     Expected design points/iter (2*100+1): 201
#     Implied avg samples/point: 62.2
#
# ADAM on SSCONT-1 (dim=2):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 24900
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1111.1
#   Macrorep 2:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 40070
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1000.0
#   Macrorep 3:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 39770
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1428.6
#   Macrorep 4:
#     Total iterations: 16
#     Total budget used: 50000
#     Avg budget/iteration: 3125.0
#     Max budget in single iteration: 15450
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 625.0
#   Macrorep 5:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 30320
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1111.1
#
# ASTRO-DF on SSCONT-1 (dim=2):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 43384
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1666.7
#   Macrorep 2:
#     Total iterations: 33
#     Total budget used: 50000
#     Avg budget/iteration: 1515.2
#     Max budget in single iteration: 22724
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 303.0
#   Macrorep 3:
#     Total iterations: 38
#     Total budget used: 50000
#     Avg budget/iteration: 1315.8
#     Max budget in single iteration: 18981
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 263.2
#   Macrorep 4:
#     Total iterations: 10
#     Total budget used: 50000
#     Avg budget/iteration: 5000.0
#     Max budget in single iteration: 45644
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1000.0
#   Macrorep 5:
#     Total iterations: 11
#     Total budget used: 50000
#     Avg budget/iteration: 4545.5
#     Max budget in single iteration: 22070
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 909.1
#
# ASTROMoRF on SSCONT-1 (dim=2):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 8
#     Total budget used: 50000
#     Avg budget/iteration: 6250.0
#     Max budget in single iteration: 30621
#     Expected design points/iter (2*1+1): 3
#     Implied avg samples/point: 2083.3
#   Macrorep 2:
#     Total iterations: 7
#     Total budget used: 50000
#     Avg budget/iteration: 7142.9
#     Max budget in single iteration: 45095
#     Expected design points/iter (2*1+1): 3
#     Implied avg samples/point: 2381.0
#   Macrorep 3:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 27612
#     Expected design points/iter (2*1+1): 3
#     Implied avg samples/point: 3333.3
#   Macrorep 4:
#     Total iterations: 12
#     Total budget used: 50000
#     Avg budget/iteration: 4166.7
#     Max budget in single iteration: 34403
#     Expected design points/iter (2*1+1): 3
#     Implied avg samples/point: 1388.9
#   Macrorep 5:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 40803
#     Expected design points/iter (2*1+1): 3
#     Implied avg samples/point: 1851.9
#
# NELDMD on SSCONT-1 (dim=2):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 2
#     Total budget used: 50000
#     Avg budget/iteration: 25000.0
#     Max budget in single iteration: 49910
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 5000.0
#   Macrorep 2:
#     Total iterations: 19
#     Total budget used: 50000
#     Avg budget/iteration: 2631.6
#     Max budget in single iteration: 47630
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 526.3
#   Macrorep 3:
#     Total iterations: 44
#     Total budget used: 50000
#     Avg budget/iteration: 1136.4
#     Max budget in single iteration: 43460
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 227.3
#   Macrorep 4:
#     Total iterations: 47
#     Total budget used: 50000
#     Avg budget/iteration: 1063.8
#     Max budget in single iteration: 44030
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 212.8
#   Macrorep 5:
#     Total iterations: 38
#     Total budget used: 50000
#     Avg budget/iteration: 1315.8
#     Max budget in single iteration: 45140
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 263.2
#
# RNDSRCH on SSCONT-1 (dim=2):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 16630
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1111.1
#   Macrorep 2:
#     Total iterations: 12
#     Total budget used: 50000
#     Avg budget/iteration: 4166.7
#     Max budget in single iteration: 34650
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 833.3
#   Macrorep 3:
#     Total iterations: 11
#     Total budget used: 50000
#     Avg budget/iteration: 4545.5
#     Max budget in single iteration: 25500
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 909.1
#   Macrorep 4:
#     Total iterations: 9
#     Total budget used: 50000
#     Avg budget/iteration: 5555.6
#     Max budget in single iteration: 36650
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1111.1
#   Macrorep 5:
#     Total iterations: 13
#     Total budget used: 50000
#     Avg budget/iteration: 3846.2
#     Max budget in single iteration: 29890
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 769.2
#
# STRONG on SSCONT-1 (dim=2):
# ------------------------------------------------------------
#   Macrorep 1:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 49535
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1666.7
#   Macrorep 2:
#     Total iterations: 4
#     Total budget used: 50000
#     Avg budget/iteration: 12500.0
#     Max budget in single iteration: 49760
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 2500.0
#   Macrorep 3:
#     Total iterations: 3
#     Total budget used: 50000
#     Avg budget/iteration: 16666.7
#     Max budget in single iteration: 49825
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 3333.3
#   Macrorep 4:
#     Total iterations: 5
#     Total budget used: 50000
#     Avg budget/iteration: 10000.0
#     Max budget in single iteration: 49690
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 2000.0
#   Macrorep 5:
#     Total iterations: 6
#     Total budget used: 50000
#     Avg budget/iteration: 8333.3
#     Max budget in single iteration: 49760
#     Expected design points/iter (2*2+1): 5
#     Implied avg samples/point: 1666.7

# %% [markdown]
# # ASTROMoRF Diagnostics
#
# This section summarizes ASTROMoRF diagnostics (log files and in-memory solver state) for quick inspection. Run this after you have executed the experiment cells.

# %%
import glob
import pathlib
from IPython.display import display, Markdown


def _summarize_log_file(path):
    print(f"--- {path} ---")
    try:
        with open(path, 'r') as f:
            lines = f.readlines()
    except Exception as e:
        print("Could not read file:", e)
        return
    tail = lines[-200:]
    for L in tail:
        if any(kw in L for kw in ['Adaptive subspace dimension change', 'Plateau detected', 'recommended_dimension', 'validation_by_d', 'relative_improvement', 'Iteration']):
            print(L.strip())
    changes = sum(1 for L in lines if 'Adaptive subspace dimension change' in L)
    print(f"Adaptive subspace changes (total in file): {changes}\n")


def scan_diagnostics(problems=['ROSENBROCK-1','SSCONT-1']):
    base = pathlib.Path.cwd().parent / 'Diagnostics'
    if not base.exists():
        base = pathlib.Path('Diagnostics')
    print('Diagnostics dir:', base)
    for prob in problems:
        pattern = str(base / f"**/astromorf_diagnostics_{prob}_*.txt")
        files = glob.glob(pattern, recursive=True)
        if not files:
            print(f"No diagnostics files for {prob}")
            continue
        files_sorted = sorted(files)
        print(f"Found {len(files_sorted)} files for {prob}; showing up to last 5 files summaries:\n")
        for p in files_sorted[-5:]:
            _summarize_log_file(p)


def summarize_in_memory(problems=['ROSENBROCK-1','SSCONT-1']):
    if 'mymetaexperiment' not in globals():
        print("mymetaexperiment not in globals(); run the experiment cells first to populate it.")
        return
    for solver_group in mymetaexperiment.experiments:
        for ps in solver_group:
            try:
                solver = ps.solver
                problem = ps.problem
            except Exception:
                continue
            if solver.name != 'ASTROMORF' or problem.name not in problems:
                continue
            print(f"=== In-memory: Solver={solver.name} Problem={problem.name} ===")
            print(' current d:', getattr(solver, 'd', None))
            print(' d_history (last 10):', getattr(solver, 'd_history', [])[-10:])
            print(' consecutive_unsuccessful:', getattr(solver, 'consecutive_unsuccessful', None))
            print(' recent_prediction_errors:', getattr(solver, 'recent_prediction_errors', []))
            prev = getattr(solver, 'previous_model_information', [])
            print(' previous_model_information entries:', len(prev))
            for i, info in enumerate(prev[-5:]):
                print(f"  entry {len(prev)-5+i}: recommended_dimension={info.get('recommended_dimension')}, validation_by_d={info.get('validation_by_d')}")
            print('\n')


# Run both scanners by default
scan_diagnostics()
print('\n')
summarize_in_memory()
# Out:
# Diagnostics dir: /Users/benjaminrees/Desktop/simopt/Diagnostics
# Found 568 files for ROSENBROCK-1; showing up to last 5 files summaries:
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-4_on_ROSENBROCK-1/astromorf_diagnostics_ROSENBROCK-1_2026-01-07_18-13-13_pid82369_r1301.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-4_on_ROSENBROCK-1/astromorf_diagnostics_ROSENBROCK-1_2026-01-07_18-13-13_pid82370_r8226.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-4_on_ROSENBROCK-1/astromorf_diagnostics_ROSENBROCK-1_2026-01-07_18-14-11_pid82453_r8523.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-4_on_ROSENBROCK-1/astromorf_diagnostics_ROSENBROCK-1_2026-01-07_18-14-11_pid82454_r1299.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-4_on_ROSENBROCK-1/astromorf_diagnostics_ROSENBROCK-1_2026-01-07_18-14-11_pid82455_r5881.txt ---
# Adaptive subspace changes (total in file): 0
#
# Found 112 files for SSCONT-1; showing up to last 5 files summaries:
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-1_on_SSCONT-1/astromorf_diagnostics_SSCONT-1_2026-01-07_18-08-43_pid81946_r9120.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-1_on_SSCONT-1/astromorf_diagnostics_SSCONT-1_2026-01-07_18-08-43_pid81949_r1577.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-1_on_SSCONT-1/astromorf_diagnostics_SSCONT-1_2026-01-07_18-14-41_pid82455_r4735.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-1_on_SSCONT-1/astromorf_diagnostics_SSCONT-1_2026-01-07_18-14-43_pid82456_r5982.txt ---
# Adaptive subspace changes (total in file): 0
#
# --- /Users/benjaminrees/Desktop/simopt/Diagnostics/ASTROMoRF-subspace-1_on_SSCONT-1/astromorf_diagnostics_SSCONT-1_2026-01-07_18-14-43_pid82460_r2727.txt ---
# Adaptive subspace changes (total in file): 0
